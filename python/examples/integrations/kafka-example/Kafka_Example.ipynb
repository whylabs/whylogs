# %% [markdown]
# # Profiling with `whylogs` from a Kafka topic
#
# In this example we will show how you can profile and merge different profiles from a Kafka topic. To simplify our example and make it reproducible anywhere, we will create a Kafka topic, generate the data from an existing CSV file and ingest it, consume the messages from the topic and then profile these consumed messages.
#
# >**NOTE**: In order to get this example going, we will use Apache Zookeper and Apache Kafka locally with Docker Compose, so be sure to have it installed and ready in your environment. If you want to read more on how this YAML file was built, check out [this blogpost](https://medium.com/better-programming/your-local-event-driven-environment-using-dockerised-kafka-cluster-6e84af09cd95).

# %% [markdown]
# To get things going, we will put the services up and create the topic in kafka with the following commands:
#
# ```bash
# $ docker-compose up -d
#
# % docker exec -ti kafka bash
#
# root@kafka: kafka-topics --create --bootstrap-server localhost:9092 --replication-factor 1 --partitions 1 --topic whylogs-stream
# ```
#
# If you haven't already, make sure to also install `kafka-python` and `whylogs` in your environment by uncommenting the following cell.

# %%
# %pip install -q whylogs
# %pip install -q kafka-python

# %% [markdown]
# ## Generating Data

# %%
import json
import os.path
import warnings

import pandas as pd
from kafka import KafkaProducer


warnings.simplefilter("ignore")

producer = KafkaProducer(bootstrap_servers='localhost:9092',
                         value_serializer=lambda v: json.dumps(v).encode('utf-8'))


data_file = "lending_club_demo.csv"
full_data = pd.read_csv(os.path.join(data_file))

data = full_data[full_data['issue_d'] == 'Jan-2017']

for i, row in data.iterrows():
    producer.send('whylogs-stream', row.to_dict())

# %% [markdown]
# ## Consuming the messages with KafkaConsumer

# %%
from kafka import KafkaConsumer, TopicPartition


consumer = KafkaConsumer(bootstrap_servers='localhost:9092', 
                         value_deserializer=lambda x: json.loads(x.decode('utf-8')))

assignments = []
topics=['whylogs-stream']

for topic in topics:
    partitions = consumer.partitions_for_topic(topic)
    for p in partitions:
        print(f'topic {topic} - partition {p}')
        assignments.append(TopicPartition(topic, p))
consumer.assign(assignments)
# Out:
# topic whylogs-stream - partition 0

# %% [markdown]
# ## Profiling with `whylogs`
#
# For the sake of simplicity, we will build a `pandas.DataFrame` from the read messages and then profile and merge until there aren't more messages in the topic.

# %%
import whylogs as why
import pandas as pd 


consumer.seek_to_beginning()

total = 0 
counter = 0
while True:
    finished = True
    record = consumer.poll(timeout_ms=500, max_records=100, update_offsets=True)
    for k,v in record.items():
        print(f'{k} - {len(v)}')
        df = pd.DataFrame([row.value for row in v])
        if counter == 0:
            profile = why.log(df).profile()
        else:
            profile.track(df)
        total += len(v)
        finished = False
        counter += 1
        
    if finished:
        print(f"total {total}")
        break
# Out:
# TopicPartition(topic='whylogs-stream', partition=0) - 100
# TopicPartition(topic='whylogs-stream', partition=0) - 100
# TopicPartition(topic='whylogs-stream', partition=0) - 68
# TopicPartition(topic='whylogs-stream', partition=0) - 41
# total 309

# %%
profile.view().to_pandas()
# Out:
#                             counts/n  counts/null  types/integral  \
# column
# verification_status              309            0               0
# settlement_percentage            309          309               0
# total_rec_prncp                  309            0               0
# num_accts_ever_120_pd            309            0               0
# all_util                         309            0               0
# ...                              ...          ...             ...
# collections_12_mths_ex_med       309            0               0
# mths_since_rcnt_il               309            5               0
# mths_since_last_record           309          250               0
# sec_app_num_rev_accts            309          309               0
# settlement_date                  309          309               0
#
#                             types/fractional  types/boolean  types/string  \
# column
# verification_status                        0              0           309
# settlement_percentage                      0              0             0
# total_rec_prncp                          309              0             0
# num_accts_ever_120_pd                    309              0             0
# all_util                                 309              0             0
# ...                                      ...            ...           ...
# collections_12_mths_ex_med               309              0             0
# mths_since_rcnt_il                       304              0             0
# mths_since_last_record                    59              0             0
# sec_app_num_rev_accts                      0              0             0
# settlement_date                            0              0             0
#
#                             types/object  cardinality/est  \
# column
# verification_status                    0         3.000000
# settlement_percentage                  0         0.000000
# total_rec_prncp                        0       276.000188
# num_accts_ever_120_pd                  0         9.000000
# all_util                               0        87.000019
# ...                                  ...              ...
# collections_12_mths_ex_med             0         3.000000
# mths_since_rcnt_il                     0        70.000012
# mths_since_last_record                 0        46.000005
# sec_app_num_rev_accts                  0         0.000000
# settlement_date                        0         0.000000
#
#                             cardinality/upper_1  cardinality/lower_1  \
# column
# verification_status                    3.000150                  3.0
# settlement_percentage                  0.000000                  0.0
# total_rec_prncp                      276.013969                276.0
# num_accts_ever_120_pd                  9.000450                  9.0
# all_util                              87.004362                 87.0
# ...                                         ...                  ...
# collections_12_mths_ex_med             3.000150                  3.0
# mths_since_rcnt_il                    70.003507                 70.0
# mths_since_last_record                46.002302                 46.0
# sec_app_num_rev_accts                  0.000000                  0.0
# settlement_date                        0.000000                  0.0
#
#                                               frequent_items/frequent_strings  \
# column
# verification_status         [FrequentItem(value='Not Verified', est=112, u...
# settlement_percentage                                                     NaN
# total_rec_prncp                                                           NaN
# num_accts_ever_120_pd                                                     NaN
# all_util                                                                  NaN
# ...                                                                       ...
# collections_12_mths_ex_med                                                NaN
# mths_since_rcnt_il                                                        NaN
# mths_since_last_record                                                    NaN
# sec_app_num_rev_accts                                                     NaN
# settlement_date                                                           NaN
#
#                                           type  distribution/mean  \
# column
# verification_status         SummaryType.COLUMN                NaN
# settlement_percentage       SummaryType.COLUMN           0.000000
# total_rec_prncp             SummaryType.COLUMN        5266.577896
# num_accts_ever_120_pd       SummaryType.COLUMN           0.488673
# all_util                    SummaryType.COLUMN          56.757282
# ...                                        ...                ...
# collections_12_mths_ex_med  SummaryType.COLUMN           0.035599
# mths_since_rcnt_il          SummaryType.COLUMN          23.013158
# mths_since_last_record      SummaryType.COLUMN          64.932203
# sec_app_num_rev_accts       SummaryType.COLUMN           0.000000
# settlement_date             SummaryType.COLUMN           0.000000
#
#                             distribution/stddev  distribution/n  \
# column
# verification_status                         NaN             NaN
# settlement_percentage                  0.000000             0.0
# total_rec_prncp                     6502.059928           309.0
# num_accts_ever_120_pd                  1.283272           309.0
# all_util                              21.046084           309.0
# ...                                         ...             ...
# collections_12_mths_ex_med             0.270932           309.0
# mths_since_rcnt_il                    27.996225           304.0
# mths_since_last_record                25.625193            59.0
# sec_app_num_rev_accts                  0.000000             0.0
# settlement_date                        0.000000             0.0
#
#                             distribution/max  distribution/min  \
# column
# verification_status                      NaN               NaN
# settlement_percentage                    NaN               NaN
# total_rec_prncp                      35000.0             262.7
# num_accts_ever_120_pd                    9.0               0.0
# all_util                               117.0               2.0
# ...                                      ...               ...
# collections_12_mths_ex_med               4.0               0.0
# mths_since_rcnt_il                     228.0               1.0
# mths_since_last_record                 111.0              17.0
# sec_app_num_rev_accts                    NaN               NaN
# settlement_date                          NaN               NaN
#
#                             distribution/q_01  distribution/q_05  \
# column
# verification_status                       NaN                NaN
# settlement_percentage                     NaN                NaN
# total_rec_prncp                        349.44             848.91
# num_accts_ever_120_pd                    0.00               0.00
# all_util                                 8.00              22.00
# ...                                       ...                ...
# collections_12_mths_ex_med               0.00               0.00
# mths_since_rcnt_il                       1.00               3.00
# mths_since_last_record                  17.00              19.00
# sec_app_num_rev_accts                     NaN                NaN
# settlement_date                           NaN                NaN
#
#                             distribution/q_10  distribution/q_25  \
# column
# verification_status                       NaN                NaN
# settlement_percentage                     NaN                NaN
# total_rec_prncp                       1228.39            1697.63
# num_accts_ever_120_pd                    0.00               0.00
# all_util                                29.00              43.00
# ...                                       ...                ...
# collections_12_mths_ex_med               0.00               0.00
# mths_since_rcnt_il                       4.00               7.00
# mths_since_last_record                  27.00              44.00
# sec_app_num_rev_accts                     NaN                NaN
# settlement_date                           NaN                NaN
#
#                             distribution/median  distribution/q_75  \
# column
# verification_status                         NaN                NaN
# settlement_percentage                       NaN                NaN
# total_rec_prncp                          2965.6            5597.33
# num_accts_ever_120_pd                       0.0               0.00
# all_util                                   58.0              72.00
# ...                                         ...                ...
# collections_12_mths_ex_med                  0.0               0.00
# mths_since_rcnt_il                         14.0              27.00
# mths_since_last_record                     68.0              84.00
# sec_app_num_rev_accts                       NaN                NaN
# settlement_date                             NaN                NaN
#
#                             distribution/q_90  distribution/q_95  \
# column
# verification_status                       NaN                NaN
# settlement_percentage                     NaN                NaN
# total_rec_prncp                      11347.67            20000.0
# num_accts_ever_120_pd                    2.00                4.0
# all_util                                83.00               89.0
# ...                                       ...                ...
# collections_12_mths_ex_med               0.00                0.0
# mths_since_rcnt_il                      52.00               88.0
# mths_since_last_record                  95.00              102.0
# sec_app_num_rev_accts                     NaN                NaN
# settlement_date                           NaN                NaN
#
#                             distribution/q_99  ints/max  ints/min
# column
# verification_status                       NaN       NaN       NaN
# settlement_percentage                     NaN       NaN       NaN
# total_rec_prncp                       35000.0       NaN       NaN
# num_accts_ever_120_pd                     7.0       NaN       NaN
# all_util                                102.0       NaN       NaN
# ...                                       ...       ...       ...
# collections_12_mths_ex_med                1.0       NaN       NaN
# mths_since_rcnt_il                      164.0       NaN       NaN
# mths_since_last_record                  111.0       NaN       NaN
# sec_app_num_rev_accts                     NaN       NaN       NaN
# settlement_date                           NaN       NaN       NaN
#
# [150 rows x 28 columns]

# %% [markdown]
# And voilà! With just a few lines of code we could profile and track incoming messages from a Kafka topic.
# Hopefully this tutorial will get you going for your existing streaming pipelines. If there are any other integrations you wanted to see, or maybe see how other users are getting the most out of `whylogs`, please check out our [community Slack](https://bit.ly/rsqrd-slack).
